# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510J6/ai-assistant-/blob/main/2303A510j6_1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Task 1

# %%
text = input("Enter a string: ")

reversed_text = ""
for char in text:
    reversed_text = char + reversed_text

print("Reversed string:", reversed_text)
# Out:
# Enter a string: 1
# Reversed string: 1

# %% [markdown]
# Task 2

# %%
text = input("Enter a string: ")

reversed_text = ""
for char in text:
    reversed_text = char + reversed_text

print("Reversed string:", reversed_text)
# Out:
# Enter a string: 2
# Reversed string: 2

# %%
Task 3

# %%
def reverse_string(text):
    # This function returns the reversed version of the string
    return text[::-1]

user_input = input("Enter a string: ")
result = reverse_string(user_input)
print("Reversed string:", result)
# Out:
# Enter a string: 3
# Reversed string: 3

# %% [markdown]
# Task 4

# %%
text = input("Enter a string: ")

reversed_text = ""
for i in range(len(text) - 1, -1, -1):
    reversed_text += text[i]

print("Reversed string:", reversed_text)
# Out:
# Enter a string: 3
# Reversed string: 3
