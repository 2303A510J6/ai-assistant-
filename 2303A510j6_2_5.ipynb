# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510J6/ai-assistant-/blob/main/2303A510j6_2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Task 1: Refactoring Odd/Even Logic

# %%
numbers = [1, 2, 3, 4, 5, 6]
even_sum = 0
odd_sum = 0

for n in numbers:
    if n % 2 == 0:
        even_sum = even_sum + n
    else:
        odd_sum = odd_sum + n

print("Even sum:", even_sum)
print("Odd sum:", odd_sum)
# Out:
# Even sum: 12
# Odd sum: 9

# %% [markdown]
# Task 2: Area Calculation Explanation

# %%
def calculate_area(shape, value1, value2=0):
    if shape == "circle":
        return 3.14 * value1 * value1
    elif shape == "rectangle":
        return value1 * value2
    elif shape == "square":
        return value1 * value1

# %%
Task 3: Prompt Sensitivity Experiment

# %%
text = input("Enter string: ")
reversed_text = ""

for char in text:
    reversed_text = char + reversed_text

print(reversed_text)
# Out:
# Enter string: 2
# 2
