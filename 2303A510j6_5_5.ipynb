# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510J6/ai-assistant-/blob/main/2303A510j6_5_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Transparency in Algorithm Optimization

# %%
import math

def is_prime_optimized(n):
    if n <= 1:
        return False
    for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# Task 2: Transparency in Recursive Algorithms (Fibonacci)

# %%
def fibonacci(n):
    # Base case 1: Fibonacci of 0 is 0
    if n == 0:
        return 0

    # Base case 2: Fibonacci of 1 is 1
    if n == 1:
        return 1

    # Recursive call: sum of previous two Fibonacci numbers
    return fibonacci(n - 1) + fibonacci(n - 2)

# %% [markdown]
# Task 3: Transparency in Error Handling

# %%
def read_file(filename):
    try:
        file = open(filename, 'r')
        data = file.read()
        file.close()
        return data

    except FileNotFoundError:
        print("Error: File not found.")

    except PermissionError:
        print("Error: Permission denied.")

    except Exception as e:
        print("Unexpected error:", e)

# %% [markdown]
# Task 4: Security in User Authentication

# %%
import hashlib

stored_password_hash = hashlib.sha256("admin123".encode()).hexdigest()

username = input("Enter username: ")
password = input("Enter password: ")

password_hash = hashlib.sha256(password.encode()).hexdigest()

if username == "admin" and password_hash == stored_password_hash:
    print("Login successful")
else:
    print("Login failed")
# Out:
# Enter username: 2
# Enter password: 33
# Login failed

# %% [markdown]
# Task 5: Privacy in Data Logging

# %%
def log_activity(username, ip):
    print(f"User {username} logged in from IP {ip}")

# %%
import datetime

def log_activity(username):
    masked_user = username[0] + "***"
    timestamp = datetime.datetime.now()
    print(f"User {masked_user} logged in at {timestamp}")
