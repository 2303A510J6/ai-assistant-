# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510J6/ai-assistant-/blob/main/2303A510j6_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Task 1

# %%
n = int(input("Enter a number: "))

result = 1
i = 1

while i <= n:
    result = result * i
    i += 1

print("Factorial is:", result)
# Out:
# Enter a number: 1
# Factorial is: 1

# %% [markdown]
# Task 2

# %%
n = int(input("Enter a number: "))

result = 1
i = 1

while i <= n:
    result = result * i
    i += 1

print("Factorial is:", result)
# Out:
# Enter a number: 2
# Factorial is: 2

# %% [markdown]
# Task 3

# %%
def calculate_factorial(number):
    # This function calculates factorial of a number
    factorial = 1
    for i in range(1, number + 1):
        factorial *= i
    return factorial


num = int(input("Enter a number: "))
result = calculate_factorial(num)
print("Factorial is:", result)
# Out:
# Enter a number: 3
# Factorial is: 6

# %% [markdown]
# Task 5 Iterative Version

# %%
def factorial_iterative(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

num = int(input("Enter number: "))
print(factorial_iterative(num))
# Out:
# Enter number: 4
# 24

# %% [markdown]
# Recursive Version

# %%
def factorial_recursive(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial_recursive(n - 1)

num = int(input("Enter number: "))
print(factorial_recursive(num))
# Out:
# Enter number: 5
# 120
